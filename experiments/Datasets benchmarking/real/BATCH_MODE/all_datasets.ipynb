# %%
import sys
import os
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np


# batch
ax = plt.axes()
line1 = ax.bar(0, ((73.88-67.36)/67.36)*100, color='b', label="ELEC 2", align='center')
#ax.bar(0, 73.88, color='b', label="ELEC 2", align='center')
ax.bar(1, ((65.55-67.36)/67.36)*100, color='b', align='center') #leveliw
#ax.bar(1, 100-65.55, color='b', align='center')
#bottom=menMeans,
line2 = ax.bar(3, ((76.37-68.75)/68.75)*100, color='r', label="NOAA", align='center')
ax.bar(4, ((74.28-68.75)/68.75)*100, color='r', align='center')

line3 = ax.bar(6, ((90.13-87.03)/87.03)*100, color='g', label="Keyboard", align='center')
ax.bar(7, ((90.65-87.03)/87.03)*100, color='g', align='center')

ax.legend(handles=[line1, line2, line3])

#plt.title("Error reduction percentage")
#plt.xlabel("Methods")
plt.ylabel("Error reduction (%)")
#plt.yticks(range(0, 101, 10))
plt.xticks(range(8), ["Static", "Dynamic", "", "Static", "Dynamic", "", "Static", "Dynamic"])
plt.xticks(rotation=90)
plt.grid()
plt.show()
    
# stream
ax = plt.axes()
line1 = ax.bar(0, ((67.74-61.71)/61.71)*100, color='b', label="ELEC 2", align='center')
ax.bar(1, ((71.58-61.71)/61.71)*100, color='b', align='center')

line2 = ax.bar(3, ((70.06-68.77)/68.77)*100, color='r', label="NOAA", align='center')
ax.bar(4, ((66.39-68.77)/68.77)*100, color='r', align='center')

line3 = ax.bar(6, ((89.30-85.86)/85.86)*100, color='g', label="Keyboard", align='center')
ax.bar(7, ((89.03-85.86)/85.86)*100, color='g', align='center')

ax.legend(handles=[line1, line2, line3])

#plt.title("Error reduction percentage")
#plt.xlabel("Methods")
plt.ylabel("Error reduction (%)")
#plt.yticks(range(0, 101, 10))
plt.xticks(range(8), ["Static", "Dynamic", "", "Static", "Dynamic", "", "Static", "Dynamic"])
plt.xticks(rotation=90)
plt.grid()
plt.show()
